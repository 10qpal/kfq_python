# %%
import pandas as pd

# %% [markdown]
# ##### 1. 주민등록인구및세대현황.csv 가지고 와서 데이터 프레임으로 작성합니다.

# %%
df = pd.read_csv('주민등록인구및세대현황.csv', encoding='cp949')

# %%
df
# Out:
#                               행정구역 2020년06월_총인구수 2020년06월_세대수  \
# 0              서울특별시  (1100000000)     9,720,846    4,384,076
# 1           서울특별시 종로구 (1111000000)       150,383       74,497
# 2      서울특별시 종로구 청운효자동(1111051500)        12,609        5,395
# 3        서울특별시 종로구 사직동(1111053000)         9,506        4,717
# 4        서울특별시 종로구 삼청동(1111054000)         2,707        1,370
# ...                            ...           ...          ...
# 3818  제주특별자치도 서귀포시 서홍동(5013058000)        10,416        4,259
# 3819  제주특별자치도 서귀포시 대륜동(5013059000)        14,514        6,342
# 3820  제주특별자치도 서귀포시 대천동(5013060000)        13,820        6,258
# 3821  제주특별자치도 서귀포시 중문동(5013061000)        11,515        5,439
# 3822  제주특별자치도 서귀포시 예래동(5013062000)         3,935        1,950
#
#       2020년06월_세대당 인구 2020년06월_남자 인구수 2020년06월_여자 인구수  2020년06월_남여 비율
# 0                2.22       4,732,275       4,988,571            0.95
# 1                2.02          73,288          77,095            0.95
# 2                2.34           5,885           6,724            0.88
# 3                2.02           4,281           5,225            0.82
# 4                1.98           1,301           1,406            0.93
# ...               ...             ...             ...             ...
# 3818             2.45           5,160           5,256            0.98
# 3819             2.29           7,359           7,155            1.03
# 3820             2.21           7,011           6,809            1.03
# 3821             2.12           5,926           5,589            1.06
# 3822             2.02           2,041           1,894            1.08
#
# [3823 rows x 7 columns]

# %% [markdown]
# ##### 2. 인구정보 데이터 프레임의 컬럼명을 행정구역, 총인구수, 세대수, 세대당인구, 남자, 여자, 남녀비율 로 변경하세요

# %%
df.columns = ['행정구역', '총인구수', '세대수', '세대당인구', '남자', '여자', '남녀비율']

# %%
df
# Out:
#                               행정구역       총인구수        세대수  세대당인구         남자  \
# 0              서울특별시  (1100000000)  9,720,846  4,384,076   2.22  4,732,275
# 1           서울특별시 종로구 (1111000000)    150,383     74,497   2.02     73,288
# 2      서울특별시 종로구 청운효자동(1111051500)     12,609      5,395   2.34      5,885
# 3        서울특별시 종로구 사직동(1111053000)      9,506      4,717   2.02      4,281
# 4        서울특별시 종로구 삼청동(1111054000)      2,707      1,370   1.98      1,301
# ...                            ...        ...        ...    ...        ...
# 3818  제주특별자치도 서귀포시 서홍동(5013058000)     10,416      4,259   2.45      5,160
# 3819  제주특별자치도 서귀포시 대륜동(5013059000)     14,514      6,342   2.29      7,359
# 3820  제주특별자치도 서귀포시 대천동(5013060000)     13,820      6,258   2.21      7,011
# 3821  제주특별자치도 서귀포시 중문동(5013061000)     11,515      5,439   2.12      5,926
# 3822  제주특별자치도 서귀포시 예래동(5013062000)      3,935      1,950   2.02      2,041
#
#              여자  남녀비율
# 0     4,988,571  0.95
# 1        77,095  0.95
# 2         6,724  0.88
# 3         5,225  0.82
# 4         1,406  0.93
# ...         ...   ...
# 3818      5,256  0.98
# 3819      7,155  1.03
# 3820      6,809  1.03
# 3821      5,589  1.06
# 3822      1,894  1.08
#
# [3823 rows x 7 columns]

# %% [markdown]
# ##### 3. 남녀비율 컬럼을 제거합니다.

# %%
df = df.drop(['남녀비율'], axis=1)

# %%
df
# Out:
#                               행정구역       총인구수        세대수  세대당인구         남자  \
# 0              서울특별시  (1100000000)  9,720,846  4,384,076   2.22  4,732,275
# 1           서울특별시 종로구 (1111000000)    150,383     74,497   2.02     73,288
# 2      서울특별시 종로구 청운효자동(1111051500)     12,609      5,395   2.34      5,885
# 3        서울특별시 종로구 사직동(1111053000)      9,506      4,717   2.02      4,281
# 4        서울특별시 종로구 삼청동(1111054000)      2,707      1,370   1.98      1,301
# ...                            ...        ...        ...    ...        ...
# 3818  제주특별자치도 서귀포시 서홍동(5013058000)     10,416      4,259   2.45      5,160
# 3819  제주특별자치도 서귀포시 대륜동(5013059000)     14,514      6,342   2.29      7,359
# 3820  제주특별자치도 서귀포시 대천동(5013060000)     13,820      6,258   2.21      7,011
# 3821  제주특별자치도 서귀포시 중문동(5013061000)     11,515      5,439   2.12      5,926
# 3822  제주특별자치도 서귀포시 예래동(5013062000)      3,935      1,950   2.02      2,041
#
#              여자
# 0     4,988,571
# 1        77,095
# 2         6,724
# 3         5,225
# 4         1,406
# ...         ...
# 3818      5,256
# 3819      7,155
# 3820      6,809
# 3821      5,589
# 3822      1,894
#
# [3823 rows x 6 columns]

# %% [markdown]
# ##### 4. 행정구역 컬럼의 ‘(’ ‘)’를 제거하고 시,구,동 컬럼을 만들어 분리해 넣고 대구지역의 값만 가지고 와서 인덱스를 새로 부여합니다.

# %%
df['행정구역'] = df['행정구역'].str.split('(').str[0]
print(df['행정구역'])
print()
df['시'] = df['행정구역'].str.split(' ').str[0]
df['구'] = df['행정구역'].str.split(' ').str[1]
df['동'] = df['행정구역'].str.split(' ').str[2]
print(df['시'])
print()
print(df['구'])
print()
print(df['동'])
# Out:
# 0                서울특별시
# 1             서울특별시 종로구
# 2        서울특별시 종로구 청운효자동
# 3          서울특별시 종로구 사직동
# 4          서울특별시 종로구 삼청동
#               ...
# 3818    제주특별자치도 서귀포시 서홍동
# 3819    제주특별자치도 서귀포시 대륜동
# 3820    제주특별자치도 서귀포시 대천동
# 3821    제주특별자치도 서귀포시 중문동
# 3822    제주특별자치도 서귀포시 예래동
# Name: 행정구역, Length: 3823, dtype: object
#
# 0         서울특별시
# 1         서울특별시
# 2         서울특별시
# 3         서울특별시
# 4         서울특별시
#          ...
# 3818    제주특별자치도
# 3819    제주특별자치도
# 3820    제주특별자치도
# 3821    제주특별자치도
# 3822    제주특별자치도
# Name: 시, Length: 3823, dtype: object
#
# 0
# 1        종로구
# 2        종로구
# 3        종로구
# 4        종로구
#         ...
# 3818    서귀포시
# 3819    서귀포시
# 3820    서귀포시
# 3821    서귀포시
# 3822    서귀포시
# Name: 구, Length: 3823, dtype: object
#
# 0
# 1
# 2       청운효자동
# 3         사직동
# 4         삼청동
#         ...
# 3818      서홍동
# 3819      대륜동
# 3820      대천동
# 3821      중문동
# 3822      예래동
# Name: 동, Length: 3823, dtype: object

# %%
condition = (df['시'] == '대구광역시')
df_daegu = df[condition]
df_daegu = df_daegu.reset_index(drop=True)

# %%
df_daegu
# Out:
#               행정구역       총인구수        세대수  세대당인구         남자         여자      시  \
# 0          대구광역시    2,427,954  1,046,585   2.32  1,198,815  1,229,139  대구광역시
# 1        대구광역시 중구      76,984     38,954   1.98     37,036     39,948  대구광역시
# 2     대구광역시 중구 동인동      8,755      5,183   1.69      4,341      4,414  대구광역시
# 3     대구광역시 중구 삼덕동      6,733      4,018   1.68      3,186      3,547  대구광역시
# 4    대구광역시 중구 성내1동      5,033      3,349   1.50      2,394      2,639  대구광역시
# ..             ...        ...        ...    ...        ...        ...    ...
# 145  대구광역시 달성군 옥포읍     25,236     10,907   2.31     12,774     12,462  대구광역시
# 146  대구광역시 달성군 현풍읍     23,509     11,775   2.00     12,263     11,246  대구광역시
# 147  대구광역시 달성군 가창면      8,041      3,754   2.14      4,004      4,037  대구광역시
# 148  대구광역시 달성군 하빈면      3,725      2,025   1.84      2,014      1,711  대구광역시
# 149  대구광역시 달성군 구지면      9,514      4,775   1.99      5,104      4,410  대구광역시
#
#        구     동
# 0
# 1     중구
# 2     중구   동인동
# 3     중구   삼덕동
# 4     중구  성내1동
# ..   ...   ...
# 145  달성군   옥포읍
# 146  달성군   현풍읍
# 147  달성군   가창면
# 148  달성군   하빈면
# 149  달성군   구지면
#
# [150 rows x 9 columns]

# %% [markdown]
# ##### 5. 총인구수, 남자, 여자 컬럼의 데이타 타입을 정수형으로 변경합니다.

# %%
df_daegu['총인구수'] = df_daegu['총인구수'].str.replace(',', '').astype('int64')
df_daegu['남자'] = df_daegu['남자'].str.replace(',', '').astype('int64')
df_daegu['여자'] = df_daegu['여자'].str.replace(',', '').astype('int64')

# %%
df_daegu
# Out:
#               행정구역     총인구수        세대수  세대당인구       남자       여자      시    구  \
# 0          대구광역시    2427954  1,046,585   2.32  1198815  1229139  대구광역시
# 1        대구광역시 중구     76984     38,954   1.98    37036    39948  대구광역시   중구
# 2     대구광역시 중구 동인동     8755      5,183   1.69     4341     4414  대구광역시   중구
# 3     대구광역시 중구 삼덕동     6733      4,018   1.68     3186     3547  대구광역시   중구
# 4    대구광역시 중구 성내1동     5033      3,349   1.50     2394     2639  대구광역시   중구
# ..             ...      ...        ...    ...      ...      ...    ...  ...
# 145  대구광역시 달성군 옥포읍    25236     10,907   2.31    12774    12462  대구광역시  달성군
# 146  대구광역시 달성군 현풍읍    23509     11,775   2.00    12263    11246  대구광역시  달성군
# 147  대구광역시 달성군 가창면     8041      3,754   2.14     4004     4037  대구광역시  달성군
# 148  대구광역시 달성군 하빈면     3725      2,025   1.84     2014     1711  대구광역시  달성군
# 149  대구광역시 달성군 구지면     9514      4,775   1.99     5104     4410  대구광역시  달성군
#
#         동
# 0
# 1
# 2     동인동
# 3     삼덕동
# 4    성내1동
# ..    ...
# 145   옥포읍
# 146   현풍읍
# 147   가창면
# 148   하빈면
# 149   구지면
#
# [150 rows x 9 columns]

# %% [markdown]
# ##### 6. 동별로 대구 인구를 차트로 표시합니다.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

import warnings
warnings.filterwarnings('ignore')
mpl.rcParams['axes.unicode_minus'] = False

x = df_daegu['구'].unique()
y = df_daegu.groupby('구')['총인구수'].sum()
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ##### 7. 동별 남,여 인구를 차트로 표시합니다.

# %%
namja = df_daegu['남자'].sum()
yeoja = df_daegu['여자'].sum()
plt.bar(['남자', '여자'], [namja, yeoja])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ##### 8. Choropleth, geojson 등을 이용하여 동별 인구수를 색상별로 지도에 나타내시오
