# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[{"id":"12917629748","type":"CreateEvent","actor":{"id":654855,"login":"sryza","display_login":"sryza","gravatar_id":"","url":"https://api.github.com/users/sryza","avatar_url":"https://avatars.githubusercontent.com/u/654855?"},"repo":{"id":252806883,"name":"dagster-io/staging","url":"https://api.github.com/repos/dagster-io/staging"},"payload":{"ref":"phabricator/base/18879","ref_type":"tag","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-07-16T00:18:24Z","org":{"id":40032576,"login":"dagster-io","gravatar_id":"","url":"https://api.github.com/orgs/dagster-io","avatar_url":"https://avatars.githubusercontent.com/u/40032576?"}},{"id":"12917629739","type":"CreateEvent","actor":{"id":47975358,"login":"ozdemirgok","display_login":"ozdemirgok","gravatar_id":"","url":"https://api.github.com/users/ozdemirgok","avatar_url":"https://avatars.githubusercontent.com/u/47975358?"},"repo":{"id":280011821,"name":"ozdemirgok/cv","url":"https://api.gith
# ...

# %%
r = requests.get('http://naver.com')

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양
# ...

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0f9f24-64de96b84916a210d0138e60"\n  }, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2'

# %%
r = requests.get('http://127.0.0.1:5000/')

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!doctype html>\n<html lang="en">\n  <head>\n    <!-- Required meta tags -->\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\n    <!-- Bootstrap CSS -->\n    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">\n\n    <title>\n        HOME\n    </title>\n  </head>\n  <body>\n    \n        <nav class="navbar navbar-dark bg-dark">\n                <a class="navbar-brand" href="/">\n                  <img src="/static/img/swimming.png" width="30" height="30" class="d-inline-block align-top" alt="">\n                  Bootstrap\n                </a>\n                <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNavDropdown" aria-controls="navbarNavDropdown" aria-expanded="false" aria-label="Toggle navigation">\n     
# ...

# %%
r.url
# Out:
# 'http://127.0.0.1:5000/'

# %%
r.history
# Out:
# []

# %%
r.is_redirect
# Out:
# False

# %%
r.status_code
# Out:
# 200

# %%
r = requests.get('http://127.0.0.1:5000/a')

# %%
r
# Out:
# <Response [404]>

# %%
r.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>404 Not Found</title>\n<h1>Not Found</h1>\n<p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>\n'

# %%
r.url
# Out:
# 'http://127.0.0.1:5000/a'

# %%
r.is_redirect
# Out:
# False

# %%
r.status_code
# Out:
# 404

# %%
data = {'sm':'top_hty','fbm':'1','ie':'utf8','query':'대구'}

# %%
r = requests.get('https://search.naver.com/search.naver',params=data)

# %%
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%8C%80%EA%B5%AC'

# %%
r.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="대구 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'대구\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'대구\'의 네이버 통합검색 결과입니다."> <title>대구 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200528.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
r.headers
# Out:
# {'Date': 'Thu, 16 Jul 2020 00:40:56 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'page_uid=Uw+Absp0YiRssmjy+9GssssstVK-480682; path=/; domain=.naver.com, _naver_usersession_=lUad7+VPOLzGLyuDfq1fKw==; path=/; expires=Thu, 16-Jul-20 00:45:56 GMT; domain=.naver.com, nx_ssl=2; Domain=.naver.com; Path=/; Expires=Sat, 15-Aug-2020 00:40:56 GMT;', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; report=/p/er/post/xss', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg'}

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='_naver_usersession_', value='lUad7+VPOLzGLyuDfq1fKw==', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1594860356, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='nx_ssl', value='2', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1597452056, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='page_uid', value='Uw+Absp0YiRssmjy+9GssssstVK-480682', port=None, port_specified=False, domain='.naver.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
r.url
# Out:
# 'https://httpbin.org/get?key1=value1&key2=value2&key2=value3'

# %%
import requests

r = requests.get('https://imgnews.pstatic.net/image/396/2014/03/28/20140327020082_0_59_20140330170614.jpg?type=w647')
r.encoding = 'ISO-8859-1'
r.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x01\x88\x01\xf4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x07\x05\x08\x00\x03\x04\x02\x01\t\xff\xc4\x00J\x10\x00\x02\x01\x03\x03\x03\x03\x02\x04\x04\x03\x06\x03\x06\x03\t\x01\x02\x03\x04\x05\x11\x06\x12!\x00\x071\x13"A\x14Q\x08\x152a#Bq\x81\x16\x91\xa1$3R\xb1\xc1\xf0b\xd1\xe1\x17%Cr\x82\x92\t4S\
# ...

# %%
from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))

# %%
import requests

r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '12917867028',
#   'type': 'PushEvent',
#   'actor': {'id': 67673621,
#    'login': 'aikefu001',
#    'display_login': 'aikefu001',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aikefu001',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67673621?'},
#   'repo': {'id': 276276828,
#    'name': 'aikefu001/img001',
#    'url': 'https://api.github.com/repos/aikefu001/img001'},
#   'payload': {'push_id': 5380952969,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '45a5b516d0e20e18f9322a1b8fa8e8b4fdf84a60',
#    'before': '90e4c18f562098300c3ea4f39e1ab019cc1a9e7d',
#    'commits': [{'sha': '45a5b516d0e20e18f9322a1b8fa8e8b4fdf84a60',
#      'author': {'email': '67673621+aikefu001@users.noreply.github.com',
#       'name': 'aikefu001'},
#      'message': '2020-07-16 09:04:22 upload cdea83f98da047d5ad93c4c099ff7f48_400.jpg',
#      'distinct': True,
# ...

# %%
j = r.json()

# %%
j[0]['id']
# Out:
# '12917867028'

# %%
j[0]['repo']['id']
# Out:
# 276276828

# %%
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}

r = requests.get(url, headers=headers)

# %%
r
# Out:
# <Response [404]>

# %%
userdata = {'userid':'gildong1'}
r = requests.post('http://127.0.0.1:5000/ajaxlist', data=userdata)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[\n  {\n    "useradd": "\\ubd80\\uc0b0\\uad11\\uc5ed\\uc2dc \\ub0a8\\uad6c", \n    "userage": 33, \n    "useremail": "gildong@gmail.com", \n    "usergender": "male", \n    "userid": "gildong1", \n    "username": "\\uae38\\ub3d9", \n    "userpw": "1234", \n    "usertel": "010-1111-2222"\n  }\n]\n'

# %%
r.headers
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '275', 'Server': 'Werkzeug/1.0.0 Python/3.7.6', 'Date': 'Thu, 16 Jul 2020 01:21:21 GMT'}

# %%
r.history
# Out:
# []

# %%
userdata = {'userid':'gildong1'}
r = requests.post('http://127.0.0.1:5000/usersform', data=userdata, allow_redirects=True)

# %%
r
# Out:
# <Response [500]>

# %%
r.history
# Out:
# []

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)
payload_dict = {'key1': ['value1', 'value2']}
r2 = requests.post('https://httpbin.org/post', data=payload_dict)

# %%
r1.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": [\n      "value1", \n      "value2"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0fae8e-4f0a2849e3589c46c319f613"\n  }, \n  "json": null, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
r2.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": [\n      "value1", \n      "value2"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.22.0", \n    "X-Amzn-Trace-Id": "Root=1-5f0fae8f-d8dabe0226d66d9e5b8ede83"\n  }, \n  "json": null, \n  "origin": "1.221.125.150", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
r1.text == r2.text
# Out:
# False

# %%
import json

url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}

r1 = requests.post(url, data=json.dumps(payload))

# %%
url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}

r2 = requests.post(url, json=payload)

# %%
r1.text
# Out:
# '{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'

# %%
r2.text
# Out:
# '{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'
